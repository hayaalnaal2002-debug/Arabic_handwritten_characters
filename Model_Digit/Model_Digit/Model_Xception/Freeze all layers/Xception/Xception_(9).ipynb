# %%
# !git clone https://github.com/hossambalaha/hmbd-v1.git
# Out:
# Cloning into 'hmbd-v1'...
# remote: Enumerating objects: 54242, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 54242 (delta 1), reused 3 (delta 1), pack-reused 54235 (from 1)
# Receiving objects: 100% (54242/54242), 230.97 MiB | 14.22 MiB/s, done.
# Resolving deltas: 100% (2128/2128), done.
# Updating files: 100% (54119/54119), done.

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import cv2
import os

# %%
data_dir = '/content/hmbd-v1/Dataset'
images = []
labels = []
digits = ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']

for label, digit in enumerate(digits):
    digit_dir = os.path.join(data_dir, digit)
    if os.path.isdir(digit_dir):
        for img_name in os.listdir(digit_dir):
            img_path = os.path.join(digit_dir, img_name)
            image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            image = cv2.resize(image, (150, 150))
            images.append(image)
            labels.append(label)

images = np.array(images).reshape(-1, 150, 150, 1) / 255.0
labels = to_categorical(np.array(labels), 10)

images_rgb = np.array([cv2.cvtColor((img * 255).astype(np.uint8), cv2.COLOR_GRAY2RGB) for img in images])
images_rgb = preprocess_input(images_rgb)

X_train, X_test, y_train, y_test = train_test_split(images_rgb, labels, test_size=0.2, random_state=42)

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

train_generator = datagen.flow(X_train, y_train, batch_size=16)

# %%
xception_model = Xception(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

input_layer = Input(shape=(150, 150, 3))
x = xception_model(input_layer, training=True)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
out_layer = Dense(10, activation='softmax')(x)

model = Model(inputs=input_layer, outputs=out_layer)

model.compile(optimizer=Adam(learning_rate=0.00001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ xception (Functional)                │ (None, 5, 5, 2048)          │      20,861,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 51200)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       6,553,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 27,416,498 (104.59 MB)
#  Trainable params: 27,361,970 (104.38 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'digit_recognition_model_xception.keras',
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

history = model.fit(
    train_generator,
    epochs=20,
    validation_data=(X_test, y_test),
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.3579 - loss: 1.8623
# Epoch 1: val_accuracy improved from -inf to 0.79852, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 116s 298ms/step - accuracy: 0.3587 - loss: 1.8605 - val_accuracy: 0.7985 - val_loss: 0.6929
# Epoch 2/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8121 - loss: 0.6304
# Epoch 2: val_accuracy improved from 0.79852 to 0.91245, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 36s 153ms/step - accuracy: 0.8122 - loss: 0.6302 - val_accuracy: 0.9124 - val_loss: 0.3309
# Epoch 3/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8674 - loss: 0.4321
# Epoch 3: val_accuracy improved from 0.91245 to 0.92722, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 40s 167ms/step - accuracy: 0.8675 - loss: 0.4320 - val_accuracy: 0.9272 - val_loss: 0.2329
# Epoch 4/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8997 - loss: 0.3220
# Epoch 4: val_accuracy improved from 0.92722 to 0.94620, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 58s 243ms/step - accuracy: 0.8997 - loss: 0.3219 - val_accuracy: 0.9462 - val_loss: 0.1624
# Epoch 5/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9119 - loss: 0.2870
# Epoch 5: val_accuracy improved from 0.94620 to 0.95464, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 57s 242ms/step - accuracy: 0.9119 - loss: 0.2870 - val_accuracy: 0.9546 - val_loss: 0.1400
# Epoch 6/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9126 - loss: 0.2981
# Epoch 6: val_accuracy improved from 0.95464 to 0.95781, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 55s 233ms/step - accuracy: 0.9126 - loss: 0.2980 - val_accuracy: 0.9578 - val_loss: 0.1245
# Epoch 7/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9250 - loss: 0.2333
# Epoch 7: val_accuracy improved from 0.95781 to 0.95992, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 94s 284ms/step - accuracy: 0.9250 - loss: 0.2333 - val_accuracy: 0.9599 - val_loss: 0.1140
# Epoch 8/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9344 - loss: 0.2021
# Epoch 8: val_accuracy did not improve from 0.95992
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 33s 138ms/step - accuracy: 0.9345 - loss: 0.2021 - val_accuracy: 0.9578 - val_loss: 0.1098
# Epoch 9/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9345 - loss: 0.2268
# Epoch 9: val_accuracy improved from 0.95992 to 0.96308, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 60s 218ms/step - accuracy: 0.9345 - loss: 0.2267 - val_accuracy: 0.9631 - val_loss: 0.1071
# Epoch 10/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9274 - loss: 0.2249
# Epoch 10: val_accuracy did not improve from 0.96308
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.9274 - loss: 0.2248 - val_accuracy: 0.9610 - val_loss: 0.1025
# Epoch 11/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9478 - loss: 0.1670
# Epoch 11: val_accuracy improved from 0.96308 to 0.96519, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 56s 236ms/step - accuracy: 0.9478 - loss: 0.1671 - val_accuracy: 0.9652 - val_loss: 0.1075
# Epoch 12/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9510 - loss: 0.1532
# Epoch 12: val_accuracy improved from 0.96519 to 0.96624, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 262ms/step - accuracy: 0.9510 - loss: 0.1532 - val_accuracy: 0.9662 - val_loss: 0.0949
# Epoch 13/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9382 - loss: 0.1753
# Epoch 13: val_accuracy did not improve from 0.96624
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 34s 142ms/step - accuracy: 0.9383 - loss: 0.1753 - val_accuracy: 0.9641 - val_loss: 0.0947
# Epoch 14/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9449 - loss: 0.1755
# Epoch 14: val_accuracy did not improve from 0.96624
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 35s 145ms/step - accuracy: 0.9449 - loss: 0.1755 - val_accuracy: 0.9610 - val_loss: 0.1053
# Epoch 15/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9501 - loss: 0.1586
# Epoch 15: val_accuracy improved from 0.96624 to 0.97257, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 56s 235ms/step - accuracy: 0.9501 - loss: 0.1586 - val_accuracy: 0.9726 - val_loss: 0.0798
# Epoch 16/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9539 - loss: 0.1371
# Epoch 16: val_accuracy did not improve from 0.97257
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.9538 - loss: 0.1372 - val_accuracy: 0.9705 - val_loss: 0.0755
# Epoch 17/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9530 - loss: 0.1426
# Epoch 17: val_accuracy improved from 0.97257 to 0.97785, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 56s 236ms/step - accuracy: 0.9530 - loss: 0.1426 - val_accuracy: 0.9778 - val_loss: 0.0736
# Epoch 18/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9500 - loss: 0.1535
# Epoch 18: val_accuracy did not improve from 0.97785
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 34s 141ms/step - accuracy: 0.9500 - loss: 0.1535 - val_accuracy: 0.9757 - val_loss: 0.0735
# Epoch 19/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9572 - loss: 0.1412
# Epoch 19: val_accuracy did not improve from 0.97785
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 33s 137ms/step - accuracy: 0.9572 - loss: 0.1412 - val_accuracy: 0.9705 - val_loss: 0.0795
# Epoch 20/20
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9539 - loss: 0.1481
# Epoch 20: val_accuracy improved from 0.97785 to 0.97890, saving model to digit_recognition_model_xception.keras
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 59s 248ms/step - accuracy: 0.9539 - loss: 0.1480 - val_accuracy: 0.9789 - val_loss: 0.0669
# Restoring model weights from the end of the best epoch: 20.

# %%
train_loss = history.history['loss'][-1]
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Training Loss: {train_loss:.4f}")
print(f"Test Loss: {test_loss:.4f}")

train_accuracy = history.history['accuracy'][-1]
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Training Loss: 0.1397
# Test Loss: 0.0669
# Training Accuracy: 95.64%
# Test Accuracy: 97.89%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=digits)
disp.plot(cmap='viridis', xticks_rotation='vertical')
plt.title("Confusion Matrix")
plt.show()
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

test_image_path = '/content/0.jpg'

image = cv2.imread(test_image_path, cv2.IMREAD_GRAYSCALE)

if image is not None:
    image = cv2.resize(image, (150, 150))
    image_rgb = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
    image_rgb = image_rgb / 255.0
    image_rgb = np.expand_dims(image_rgb, axis=0)

    prediction = model.predict(image_rgb)

    predicted_class = np.argmax(prediction, axis=1)[0]

    print(f"Predicted Digit: {predicted_class}")

    plt.figure(figsize=(5, 5))
    plt.imshow(image, cmap='gray')
    plt.title(f"Predicted: {predicted_class}")
    plt.axis('off')
    plt.show()
else:
    print("Error: Unable to load the image. Please check the file path.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted Digit: 0
